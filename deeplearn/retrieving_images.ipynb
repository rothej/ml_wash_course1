# %%
import turicreate

# %%
image_train = turicreate.SFrame('~/venv/ml_wash/ml_wash_course1/deeplearn/image_train_data/')
image_test = turicreate.SFrame('~/venv/ml_wash/ml_wash_course1/deeplearn/image_test_data/')
image_data = turicreate.SFrame('~/venv/ml_wash/ml_wash_course1/deeplearn/image_train_data/')

# %%
sketch = turicreate.Sketch(image_data['label'])
